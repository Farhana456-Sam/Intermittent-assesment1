# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# Create a DataFrame `df` from this dictionary `data` which has the index `labels`
df=pd.DataFrame(data,index=labels)

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#Display a summary of the basic information about this DataFrame and its data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
#Return the first 3 rows of the DataFrame `df`.
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
#Display the 'animal' and 'age' columns from the DataFrame `df`
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
#Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'
df.loc[['d','e','i'],['animal','age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
#Select only the rows where the number of visits is greater than 3
print(df[df['visits']>3])
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
#Select the rows where the age is missing, i.e. it is `NaN`.
df[df['age'].isna()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
#Select the rows where the animal is a cat *and* the age is less than 3.
df[(df['animal']== 'cat') & (df['age'] < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
#Select the rows where the age is between 2 and 4 (inclusive)
df[(df['age'] >=2) & (df['age']<=4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
#Change the age in row 'f' to 1.5.
df.loc['f','age'] = 1.5

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#Calculate the sum of all visits in `df` (i.e. the total number of visits).
df['visits'].sum()
# Out:
# 19

# %%
#Calculate the mean age for each different animal in `df`
mean_by_age=df.groupby('animal')['age'].mean()

# %%
print(mean_by_age)
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %%
#Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.
k = {'animal':'bird','age' : 1.0,'visits':4,'priority':'no'}
df=pd.concat([df,pd.DataFrame([k])],ignore_index=True)
print("DataFrame after adding the new row")
print(df)
# Out:
# DataFrame after adding the new row
#    animal  age  visits priority
# 0     cat  2.5       1      yes
# 1     cat  3.0       3      yes
# 2   snake  0.5       2       no
# 3     dog  NaN       3      yes
# 4     dog  5.0       2       no
# 5     cat  1.5       3       no
# 6   snake  4.5       1       no
# 7     cat  NaN       1      yes
# 8     dog  7.0       2       no
# 9     dog  3.0       1       no
# 10   bird  1.0       4       no

# %%
df = df.iloc[:-1]
print("DataFrame after deleting the added row",df)
# Out:
# DataFrame after deleting the added row   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  NaN       3      yes
# 4    dog  5.0       2       no
# 5    cat  1.5       3       no
# 6  snake  4.5       1       no
# 7    cat  NaN       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %%
#Count the number of each type of animal in `df'
animal_counts = df['animal'].value_counts()
print('Animal Counts: ',animal_counts)
# Out:
# Animal Counts:  animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %%
#Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).
df.sort_values(['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# 8    dog  7.0       2       no
# 4    dog  5.0       2       no
# 6  snake  4.5       1       no
# 9    dog  3.0       1       no
# 1    cat  3.0       3      yes
# 0    cat  2.5       1      yes
# 5    cat  1.5       3       no
# 2  snake  0.5       2       no
# 7    cat  NaN       1      yes
# 3    dog  NaN       3      yes

# %%
#The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.
df['priority']=df['priority'].map({'yes':True,'no':False})

# %%
df
# Out:
#   animal  age  visits  priority
# 0    cat  2.5       1      True
# 1    cat  3.0       3      True
# 2  snake  0.5       2     False
# 3    dog  NaN       3      True
# 4    dog  5.0       2     False
# 5    cat  1.5       3     False
# 6  snake  4.5       1     False
# 7    cat  NaN       1      True
# 8    dog  7.0       2     False
# 9    dog  3.0       1     False

# %%
#In the 'animal' column, change the 'snake' entries to 'python'.
df['animal']=df['animal'].replace('snake','python')

# %%
df
# Out:
#    animal  age  visits  priority
# 0     cat  2.5       1      True
# 1     cat  3.0       3      True
# 2  python  0.5       2     False
# 3     dog  NaN       3      True
# 4     dog  5.0       2     False
# 5     cat  1.5       3     False
# 6  python  4.5       1     False
# 7     cat  NaN       1      True
# 8     dog  7.0       2     False
# 9     dog  3.0       1     False

# %%
df=df.drop(df.tail(0).index)
df
# Out:
#    animal  age  visits  priority
# 0     cat  2.5       1      True
# 1     cat  3.0       3      True
# 2  python  0.5       2     False
# 3     dog  NaN       3      True
# 4     dog  5.0       2     False
# 5     cat  1.5       3     False
# 6  python  4.5       1     False
# 7     cat  NaN       1      True
# 8     dog  7.0       2     False
# 9     dog  3.0       1     False

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\ny-flights.csv")

# %%
data
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
#Which airline ID is present maximum times in the dataset
maximum = data['airline_id'].max()

# %%
print(maximum)
# Out:
# 21171

# %%
#Draw a plot between dep_delay and arr_delay
plt.plot(data['dep_delay'],label = 'Depature Delay',linestyle="dashed",color="green",linewidth = 2)
plt.plot(data['arr_delay'],label = 'Arrival Delay',linestyle="dotted",color="red",linewidth = 2)
plt.xlabel('Depature Delay')
plt.ylabel('Arrival Delay')
plt.title('Departure vs Arrival')
plt.show()

# %%
plt.scatter(data['dep_delay'],data['arr_delay'])
plt.xlabel('Depature Delay')
plt.ylabel('Arrival Delay')
plt.title('Departure vs Arrival')
plt.show()

# %%
plt.figure(figsize=(10,6)) 
plt.barh(data['dep_delay'],data['arr_delay'])
plt.show()

# %%
sns.barplot(x = data['dep_delay'],y = data['arr_delay'])
plt.show()
